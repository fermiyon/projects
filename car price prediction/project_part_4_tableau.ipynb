# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import numpy as np
from scipy import stats
from tqdm import tqdm
import pingouin as pg
from colorama import Fore, Style
from scipy.stats import spearmanr



tqdm.pandas()

# %%
df = pd.read_csv('3_outliers_handled.csv')

# %%
df
# Out:
#                    make_model           make     model    price body_type
# 0         Mercedes-Benz A 160  Mercedes-Benz     A 160  16950.0   Compact  \
# 1       Mercedes-Benz EQE 350  Mercedes-Benz   EQE 350  80900.0   Compact
# 2      Mercedes-Benz A 45 AMG  Mercedes-Benz  A 45 AMG  69900.0   Compact
# 3      Mercedes-Benz A 35 AMG  Mercedes-Benz  A 35 AMG  46990.0   Compact
# 4      Mercedes-Benz A 45 AMG  Mercedes-Benz  A 45 AMG  16800.0   Compact
# ...                       ...            ...       ...      ...       ...
# 24802               Volvo S90          Volvo       S90  37600.0     Sedan
# 24803               Volvo S40          Volvo       S40   5499.0     Sedan
# 24804               Volvo C30          Volvo       C30   7300.0     Sedan
# 24805               Volvo S90          Volvo       S90  29900.0     Sedan
# 24806               Volvo S80          Volvo       S80   4440.0     Sedan
#
#         age      fuel      country            type warranty  ...
# 0       6.0    Diesel        Spain            Used      Yes  ...  \
# 1       0.0  Electric        Spain  Pre-registered      Yes  ...
# 2       2.0   Benzine        Spain            Used      Yes  ...
# 3       2.0   Benzine        Spain            Used      Yes  ...
# 4       7.0    Diesel        Spain            Used      Yes  ...
# ...     ...       ...          ...             ...      ...  ...
# 24802   3.0  Electric        Spain            Used      Yes  ...
# 24803  18.0   Benzine  Netherlands            Used       No  ...
# 24804  11.0    Diesel      Belgium            Used      Yes  ...
# 24805   5.0   Benzine  Netherlands            Used      Yes  ...
# 24806  20.0   Benzine  Netherlands            Used       No  ...
#
#        previous_owner energy_efficiency_class power_hp  fuel_consumption_avg
# 0                 2.0               efficient     90.0                 5.450  \
# 1                 1.0               efficient    292.0                 2.359
# 2                 2.0             inefficient    421.0                 8.400
# 3                 2.0             inefficient    306.0                 7.300
# 4                 2.0             inefficient    136.0                 4.900
# ...               ...                     ...      ...                   ...
# 24802             2.0               efficient    392.0                 2.000
# 24803             3.0               efficient    170.0                 9.100
# 24804             1.0             inefficient    114.0                 3.800
# 24805             1.0               efficient    254.0                 6.500
# 24806             5.0             inefficient    200.0                10.400
#
#                                                  address   latitude
# 0      Calle Forja 6, 11500 El Puerto de Santa María,...  36.618987  \
# 1      Calle Logroño, 28649 Rozas de Puerto Real, Mad...  40.315198
# 2              Muelle de Llevant, 43004 Tarragona, Spain  41.106726
# 3      Calle Provenza, Valle de los Molinos, 45200 Gu...  20.848540
# 4          Carril de los Aragonés 4, 30007 Murcia, Spain  38.011686
# ...                                                  ...        ...
# 24802  Calle de los Hermanos Lumière 16, 29004 Málaga...  36.693246
# 24803          Stobbeweg 6, 2461 EX Ter Aar, Netherlands  52.179041
# 24804                                      5060, Belgium  50.446949
# 24805  Bergambachterstraat 5, 2871 JB Schoonhoven, Ne...  51.955269
# 24806          Lage Ham 106, 5102 AE Dongen, Netherlands  51.637917
#
#         longitude            cc                            ss
# 0       -6.205012       premium       Safety Security Premium  \
# 1       -4.474838  premium_plus  Safety Security Premium Plus
# 2        1.249235       premium      Safety Security Standard
# 3     -103.428946       premium      Safety Security Standard
# 4       -1.089482       premium       Safety Security Premium
# ...           ...           ...                           ...
# 24802   -4.463076       premium      Safety Security Standard
# 24803    4.711120       premium       Safety Security Premium
# 24804    4.635015       premium       Safety Security Premium
# 24805    4.845520       premium  Safety Security Premium Plus
# 24806    4.931613       premium       Safety Security Premium
#
#                                  em
# 0      Entertainment Media Standard
# 1       Entertainment Media Premium
# 2      Entertainment Media Standard
# 3      Entertainment Media Standard
# 4      Entertainment Media Standard
# ...                             ...
# 24802  Entertainment Media Standard
# 24803  Entertainment Media Standard
# 24804  Entertainment Media Standard
# 24805   Entertainment Media Premium
# 24806  Entertainment Media Standard
#
# [24807 rows x 32 columns]

# %%
df.to_csv("4_tableau.csv")
